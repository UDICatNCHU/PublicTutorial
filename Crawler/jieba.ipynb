# %% [markdown]
# ## 休息一下
#
#
# ## 下午場開始
#
# 目錄：
#
# 1. 斷詞
#     * 安裝結巴
#     * 斷詞原理簡單講
#     * 下載字典
# 2. 貝氏分類器
#     * 原理
#     * 卡方
#     * 情緒字典
# 3. 實作

# %% [markdown]
# ### 安裝結巴
#
# > pip install jieba

# %% [markdown]
# ### 斷詞示範

# %%
import jieba, os
print(jieba.lcut('吉林市長春藥店'))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\udic\AppData\Local\Temp\jieba.cache
# Loading model cost 3.743 seconds.
# Prefix dict has been built succesfully.
# ['吉林市', '長', '春藥店']

# %% [markdown]
# ### 下載字典
#
# 答案不是 ~~春藥店~~
# 是**長春** **藥店**
# 但是蒐集到的單字不夠多
# 導致演算法覺得這種組合的機率很小
#
# 要改善就需要額外的字典

# %%
jieba.load_userdict(os.path.join('', 'dictionary', 'dict.txt.big.txt'))
jieba.load_userdict(os.path.join('', "dictionary", "NameDict_Ch_v2"))
print(jieba.lcut('吉林市長春藥店'))
# Out:
# ['吉林市', '長春', '藥店']

# %% [markdown]
# ## 還記得早上練習的爬蟲嘛？
# ## 把早上爬完的結果斷詞然後就可以製作情緒分類器了
#
# 下列的函式：
# 1. 濾掉Stopwords
# 2. 濾掉英文、數量詞 e.q. 一葉扁舟 一葉就是數量詞
#
# 參考自詞性表 [ICTPOS3.0词性标记集](https://gist.github.com/luw2007/6016931)

# %%
import jieba.posseg as pseg
import jieba, json

stopwords = json.load(open('stopwords/stopwords.json', 'r'))
jieba.load_userdict('dictionary/dict.txt.big.txt')
jieba.load_userdict('dictionary/NameDict_Ch_v2')
def CutAndrmStopWords(sentence):
    def condition(x):
        x = list(x)
        word, flag = x[0], x[1]
        if len(word) > 1 and flag!='eng' and flag != 'm' and flag !='mq' and word not in stopwords:
            return True
        return False

    result = filter(condition, pseg.cut(sentence))
    result = map(lambda x:list(x)[0], result)
    return list(result)

# %%
pos = json.load(open('pttPos.json', 'r'))
neg = json.load(open('pttNeg.json', 'r'))

posAfterSegment = list(map(CutAndrmStopWords, pos))
print(posAfterSegment)
print('============================上面是正面下面是負面資料============================')
print('============================上面是正面下面是負面資料============================')
print('============================上面是正面下面是負面資料============================')

negAfterSegment = list(map(CutAndrmStopWords, neg))
print(posAfterSegment)

json.dump(posAfterSegment, open('MyPos.json', 'w'))
json.dump(negAfterSegment, open('MyNeg.json', 'w'))
# Out:
# [[], [], [], ['過氣', '又來了'], ['錢錢', '發惹'], ['現在', '文摘', '先猜', '精華區', '不妙'], ['動漫', '戰女', '嘻嘻'], ['水桶', '至少', '我知道', '原因'], ['好了吧'], ['老江湖'], ['打電話', '專家'], ['決定', '砲灰'], ['版主', '水桶', '知道', '原因', '至少', '願意'], ['照顧', '我會'], [], [], ['分手', '原因'], ['屁股', '選到', '怪怪的'], ['八卦', '唯一', '求證', '爆卦', '內容', '版主'], ['發錢'], ['流來', '整治'], ['不行'], [], ['看過', '選好', '方方', '讓給', '年輕人'], [], ['喜歡你'], [], ['一定'], ['行動', '司機'], [], ['權利', '迷惑'], ['家族', '好好', '歧視'], ['偶灰', '投泥'], [], ['收費', '塑膠袋', '製造', '工廠', '環保署', '稽查', '控管', '廢掉'], [], [], [], ['基督教'], ['謝謝你', '現在', '真的', '一片空白', '只能', '發文', '方式', '紀念'], ['質詢', '睡著'], ['宮廷'], ['別鬧', '派遣'], ['民進黨', '人才', '選來', '選去'], ['陳菊', '總統', '企圖', '空心菜', '威脅', '權謀'], ['真他媽', '噁心'], ['總統', '實際行動', '發起', '罷免', '沒用', '爽爽', '任期'], ['律師', '法律系', '畢業'], [], ['現在', '真的', '來到', '成家', '年代'], ['反觀', '謝龍介'], ['哈哈哈', '小川', '暴怒'], ['甲味'], [], ['普丁'], [], ['支持', '成家'], ['最近', '政治', '迷上', '脫口秀', '段子'], ['阿謀'], [], ['鄉民', '表示', '日本', '電車', '誤點'], ['擁核', '勝利'], ['不用', '上班', '真好'], ['一
# ...
